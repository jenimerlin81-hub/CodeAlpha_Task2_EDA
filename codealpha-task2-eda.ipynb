# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df["target"] = iris.target

print("Dataset loaded successfully!")
print("Rows and Columns:", df.shape)

df.head()
# Out:
# Dataset loaded successfully!
# Rows and Columns: (150, 5)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
print("Statistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
import matplotlib.pyplot as plt

df.drop(columns=["target"]).hist(figsize=(10, 8))

plt.suptitle("Iris Dataset - Feature Distribution")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation = df.drop(columns=["target"]).corr()

sns.heatmap(correlation, annot=True, cmap="coolwarm")

plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Key Insights
#
# 1. The Iris dataset contains 150 records and 5 columns.
#
# 2. There are no missing values in the dataset.
#
# 3. The dataset contains four numerical features:
#    Sepal Length, Sepal Width, Petal Length and Petal Width.
#
# 4. Petal length and petal width show a strong positive correlation.
#
# 5. The feature distributions show differences in the measurements of Iris flowers.
#
# 6. The dataset contains three target classes representing different Iris species.

# %% [markdown]
# ## Conclusion
#
# The Exploratory Data Analysis of the Iris dataset was successfully completed.
#
# The dataset contains 150 records and 5 columns with no missing values.
# Statistical analysis and visualizations were used to understand the data.
#
# The analysis shows that petal length and petal width have a strong relationship.
# The visualizations also help us understand the distribution of different features.
#
# Overall, EDA helped us identify important patterns and characteristics in the Iris dataset.
